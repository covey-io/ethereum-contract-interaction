# %%
import pandas as pd
from alpaca_trade_api.rest import REST, TimeFrame, TimeFrameUnit
from datetime import datetime,timedelta, timezone

# %%
# initialize alpaca
api = REST(key_id = 'PKU9G2XRSNL8A1FF34C7', secret_key = 'AQe6RsvUdmZykRZCRYsNF5kEogta6DIyCApkoMAl'
          ,base_url = "https://paper-api.alpaca.markets")

# %%
from datetime import date as todaysDate
from datetime import datetime as todaysDateTime
Today_date  =  todaysDate.today()
Today_time  =  todaysDateTime.min.time()
Today_datetime = todaysDateTime.combine(Today_date, Today_time)
print(Today_datetime)
# Out:
# 2022-07-14 00:00:00

# %%
api.get_calendar("2022-07-04")
# Out:
# [Calendar({   'close': '16:00',
#      'date': '2022-07-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '13:00',
#      'date': '2022-11-25',
#      'open': '09:30',
#      'session_close': '1600',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '13:00',
#      'date': '2023-07-03',
#      'open': '09:30',
#      'session_close': '1600',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-11-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-11-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-11-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
# ...
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  ...]

# %%
datetime(1970,1,1)
# Out:
# datetime.datetime(1970, 1, 1, 0, 0)

# %%
api.get_crypto_bars("GRUB",
                                #TimeFrame(1, TimeFrameUnit.Minute),
                                TimeFrame.Hour,
                                start = "2021-01-01",
                                end=None
                               
                                ).df.reset_index()
# Out:
# Empty DataFrame
# Columns: [index]
# Index: []

# %%
tickers= [
    'RDS.A',
    'GWPH',
    'ERUS',
    'CREE',
    'CZZ',
    'RDS.B',
    'RUSL',
    'GRUB',
    'QIWI',
    'VIAC',
    'DISCK',
    'KSU',
    'BLANK',
    'TIF',
    'DNKN',
    'UN',
    'GRA',
    'LB'
]

# %%
df = api.get_bars('GRUB',
                                #TimeFrame(1, TimeFrameUnit.Minute),
                                TimeFrame.Hour,
                                start = "2022-01-01",
                                end = None
                                ).df.reset_index()

# %%
df
# Out:
#                     timestamp     open     high    low  close   volume  \
# 0   2022-01-03 09:00:00+00:00  10.9400  11.2000  10.90  11.18    64921
# 1   2022-01-03 10:00:00+00:00  11.1800  11.2600  11.13  11.18    26306
# 2   2022-01-03 11:00:00+00:00  11.1800  11.1800  11.10  11.11    20753
# 3   2022-01-03 12:00:00+00:00  11.1100  11.1600  11.10  11.16    29771
# 4   2022-01-03 13:00:00+00:00  11.1300  11.2600  11.11  11.25    59830
# ..                        ...      ...      ...    ...    ...      ...
# 646 2022-03-11 20:00:00+00:00   6.9262   6.9599   6.72   6.73  1167702
# 647 2022-03-11 21:00:00+00:00   6.7200   6.9000   6.70   6.90    68006
# 648 2022-03-11 22:00:00+00:00   6.7900   6.7900   6.73   6.73      851
# 649 2022-03-11 23:00:00+00:00   6.7300   6.7300   6.73   6.73      800
# 650 2022-03-12 00:00:00+00:00   6.7300   6.7300   6.73   6.73      600
#
#      trade_count       vwap
# 0            163  10.964407
# 1             92  11.186941
# 2             34  11.112834
# 3             69  11.123157
# 4            126  11.181260
# ..           ...        ...
# 646         5665   6.796419
# 647           19   6.720475
# 648            6   6.772303
# 649            1   6.730000
# 650            2   6.730000
#
# [651 rows x 8 columns]

# %%
df.groupby('symbol')['timestamp'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-9a0c0c52589c> in <module>
# ----> 1 df.groupby('symbol')['timestamp'].max()
#
# ~\anacondaGA\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anacondaGA\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~\anacondaGA\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 'symbol'

# %%
df = api.get_bars("ARKK",
                                #TimeFrame(1, TimeFrameUnit.Minute),
                                TimeFrame.Hour,
                                start = "2022-07-01",
                                end = None
                                ).df.reset_index()

# %%
df
# Out:
#                    timestamp   open    high     low   close   volume  \
# 0  2022-07-01 08:00:00+00:00  39.70  39.720  39.400  39.500     3696
# 1  2022-07-01 09:00:00+00:00  39.70  39.780  39.700  39.780     5879
# 2  2022-07-01 10:00:00+00:00  39.80  39.900  39.750  39.750     1538
# 3  2022-07-01 11:00:00+00:00  39.70  39.980  39.600  39.640    41589
# 4  2022-07-01 12:00:00+00:00  39.80  40.030  39.710  39.960    65784
# 5  2022-07-01 13:00:00+00:00  39.96  41.810  39.960  41.310  5188962
# 6  2022-07-01 14:00:00+00:00  41.30  41.670  40.260  40.980  5437301
# 7  2022-07-01 15:00:00+00:00  40.97  41.460  40.570  40.710  2586354
# 8  2022-07-01 16:00:00+00:00  40.69  40.820  40.315  40.330  1706834
# 9  2022-07-01 17:00:00+00:00  40.32  40.790  40.200  40.770  1755183
# 10 2022-07-01 18:00:00+00:00  40.77  41.050  40.430  40.905  1540313
# 11 2022-07-01 19:00:00+00:00  40.91  41.225  40.740  41.190  4220931
# 12 2022-07-01 20:00:00+00:00  41.22  41.380  41.100  41.210  1334662
# 13 2022-07-01 21:00:00+00:00  41.19  41.390  40.480  41.250    40840
# 14 2022-07-01 22:00:00+00:00  41.28  41.280  41.130  41.130     2079
# 15 2022-07-01 23:00:00+00:00  41.13  41.370  41.110  41.340    16756
# 16 2022-07-05 08:00:00+00:00  41.40  41.400  40.520  40.520    11438
# 17 2022-07-05 09:00:00+00:00  40.55  40.810  40.500  40.690    16221
# 18 2022-07-05 10:00:00+00:00  40.66  40.850  40.640  40.850     8146
# 19 2022-07-05 11:00:00+00:00  40.83  40.840  40.440  40.440    28052
# 20 2022-07-05 12:00:00+00:00  40.45  40.720  40.200  40.240   136288
# 21 2022-07-05 13:00:00+00:00  40.24  41.230  39.840  40.930  4999277
#
#     trade_count       vwap
# 0            45  39.483093
# 1            39  39.717666
# 2            18  39.860325
# 3           342  39.775519
# 4           642  39.865690
# 5         37463  40.859706
# 6         34861  40.965696
# 7         18423  41.084595
# 8         11918  40.582865
# 9         11062  40.530743
# 10        10297  40.794678
# 11        25376  41.057644
# 12          242  41.217708
# 13          113  41.082688
# 14           11  41.215248
# 15           94  41.262118
# 16           77  40.966859
# 17          103  40.580192
# 18           37  40.721241
# 19          223  40.695526
# 20         1345  40.492600
# 21        35338  40.441958
