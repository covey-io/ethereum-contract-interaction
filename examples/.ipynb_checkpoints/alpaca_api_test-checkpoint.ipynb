# %%
import pandas as pd
from alpaca_trade_api.rest import REST, TimeFrame, TimeFrameUnit
from datetime import datetime,timedelta, timezone

# %%
# initialize alpaca
api = REST(key_id = 'PKU9G2XRSNL8A1FF34C7', secret_key = 'AQe6RsvUdmZykRZCRYsNF5kEogta6DIyCApkoMAl'
          ,base_url = "https://paper-api.alpaca.markets")

# %%
from datetime import date as todaysDate
from datetime import datetime as todaysDateTime
Today_date  =  todaysDate.today()
Today_time  =  todaysDateTime.min.time()
Today_datetime = todaysDateTime.combine(Today_date, Today_time)
print(Today_datetime)
# Out:
# 2022-07-05 00:00:00

# %%
api.get_calendar("2022-07-04")
# Out:
# [Calendar({   'close': '16:00',
#      'date': '2022-07-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-07-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-08-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-09-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-10-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '13:00',
#      'date': '2022-11-25',
#      'open': '09:30',
#      'session_close': '1600',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-11-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2022-12-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-01-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-02-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-03-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-04-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-05-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-06-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '13:00',
#      'date': '2023-07-03',
#      'open': '09:30',
#      'session_close': '1600',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-07-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-08-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-09-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-10-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-11-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-11-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2023-11-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
# ...
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-01-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-02-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-03-31',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-04-30',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-06',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-07',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-13',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-14',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-19',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-20',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-21',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-27',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-28',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-05-29',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-01',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-02',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-03',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-04',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-05',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-08',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-09',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-10',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-11',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-12',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-15',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-16',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-17',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-18',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-22',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-23',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-24',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-25',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  Calendar({   'close': '16:00',
#      'date': '2026-06-26',
#      'open': '09:30',
#      'session_close': '2000',
#      'session_open': '0400'}),
#  ...]

# %%
datetime(1970,1,1)
# Out:
# datetime.datetime(1970, 1, 1, 0, 0)

# %%
api.get_crypto_bars("ALGOUSD",
                                #TimeFrame(1, TimeFrameUnit.Minute),
                                TimeFrame.Hour,
                                start = "2022-01-01",
                                end=None
                                ,exchanges=['FTXU']
                                ).df.reset_index()
# Out:
#                     timestamp exchange    open    high     low   close  \
# 0   2022-05-25 15:00:00+00:00     FTXU  0.4062  0.4066  0.4037  0.4066
# 1   2022-05-25 16:00:00+00:00     FTXU  0.4057  0.4057  0.4046  0.4050
# 2   2022-05-25 17:00:00+00:00     FTXU  0.4050  0.4057  0.4044  0.4044
# 3   2022-05-25 18:00:00+00:00     FTXU  0.4056  0.4079  0.4010  0.4079
# 4   2022-05-25 19:00:00+00:00     FTXU  0.4090  0.4090  0.4048  0.4048
# ..                        ...      ...     ...     ...     ...     ...
# 640 2022-06-21 11:00:00+00:00     FTXU  0.3360  0.3360  0.3296  0.3296
# 641 2022-06-21 12:00:00+00:00     FTXU  0.3306  0.3328  0.3306  0.3328
# 642 2022-06-21 13:00:00+00:00     FTXU  0.3317  0.3370  0.3284  0.3370
# 643 2022-06-21 14:00:00+00:00     FTXU  0.3372  0.3390  0.3343  0.3381
# 644 2022-06-21 15:00:00+00:00     FTXU  0.3370  0.3370  0.3310  0.3364
#
#      volume  trade_count      vwap
# 0      1297            9  0.406374
# 1     10942           12  0.405000
# 2     19449           20  0.405000
# 3       805           17  0.406095
# 4         9            4  0.406756
# ..      ...          ...       ...
# 640    1257            9  0.333023
# 641    1509            6  0.332791
# 642    2014           22  0.334226
# 643    4695           13  0.336520
# 644   10306           28  0.333973
#
# [645 rows x 9 columns]

# %%
tickers= [
    'RDS.A',
    'GWPH',
    'ERUS',
    'CREE',
    'CZZ',
    'RDS.B',
    'RUSL',
    'GRUB',
    'QIWI',
    'VIAC',
    'DISCK',
    'KSU',
    'BLANK',
    'TIF',
    'DNKN',
    'UN',
    'GRA',
    'LB'
]

# %%
df = api.get_bars(tickers,
                                #TimeFrame(1, TimeFrameUnit.Minute),
                                TimeFrame.Hour,
                                start = "2022-01-01",
                                end = None
                                ).df.reset_index()

# %%
df.groupby('symbol')['timestamp'].max()
# Out:
# symbol
# DISCK   2022-04-08 20:00:00+00:00
# ERUS    2022-03-04 00:00:00+00:00
# GRUB    2022-03-12 00:00:00+00:00
# QIWI    2022-02-28 11:00:00+00:00
# RDS.A   2022-01-28 23:00:00+00:00
# RDS.B   2022-01-28 21:00:00+00:00
# RUSL    2022-03-04 00:00:00+00:00
# VIAC    2022-02-17 00:00:00+00:00
# Name: timestamp, dtype: datetime64[ns, UTC]

# %%
df = api.get_bars("ARKK",
                                #TimeFrame(1, TimeFrameUnit.Minute),
                                TimeFrame.Hour,
                                start = "2022-07-04",
                                end = None
                                ).df.reset_index()

# %%
df
# Out:
#                   timestamp   open   high    low  close  volume  trade_count  \
# 0 2022-07-05 08:00:00+00:00  41.40  41.40  40.52  40.52   11438           77
# 1 2022-07-05 09:00:00+00:00  40.55  40.81  40.50  40.69   16221          103
# 2 2022-07-05 10:00:00+00:00  40.66  40.85  40.64  40.85    8146           37
# 3 2022-07-05 11:00:00+00:00  40.83  40.84  40.44  40.44   28052          223
# 4 2022-07-05 12:00:00+00:00  40.45  40.72  40.20  40.24  136288         1345
# 5 2022-07-05 13:00:00+00:00  40.24  40.57  40.24  40.47   48212          534
#
#         vwap
# 0  40.966859
# 1  40.580192
# 2  40.721241
# 3  40.695526
# 4  40.492600
# 5  40.373357
